'mdp.39015012111319', 
'mdp.39015030109782', 
'mdp.39015030109790', 
'mdp.39015030109808', 
'mdp.39015030109816', 
'mdp.39015030109824', 
'mdp.39015030109832', 
'mdp.39015030109840', 
'mdp.39015030109857', 
'mdp.39015030109865', 
'mdp.39015030109873', 
'mdp.39015012105238', 
]

# %%
pathlist = "pathlist.txt"
p = open(pathlist, "w+")
print("pathlist created")

for htid in htids:
    p.write(utils.id_to_rsync(htid))
    print(utils.id_to_rsync(htid))
    p.write('\n')
# Out:
# pathlist created
# chi/443/chi.43047330.json.bz2
# mdp/31341/mdp.39015030143310.json.bz2
# uc1/b058/uc1.b000555778.json.bz2
# mdp/31348/mdp.39015030143286.json.bz2
# mdp/31347/mdp.39015030143278.json.bz2
# mdp/31346/mdp.39015030143260.json.bz2
# mdp/31340/mdp.39015030142205.json.bz2
# mdp/31349/mdp.39015030142197.json.bz2
# mdp/31265/mdp.39015023266250.json.bz2
# mdp/31348/mdp.39015030142189.json.bz2
# mdp/31347/mdp.39015030142171.json.bz2
# uc1/30105/uc1.32106014606757.json.bz2
# mdp/31345/mdp.39015030142155.json.bz2
# mdp/31344/mdp.39015030142148.json.bz2
# mdp/31343/mdp.39015030142130.json.bz2
# mdp/31100/mdp.39015018008105.json.bz2
# mdp/31342/mdp.39015030142122.json.bz2
# mdp/31341/mdp.39015030142114.json.bz2
# mdp/31340/mdp.39015030142106.json.bz2
# mdp/31349/mdp.39015030142098.json.bz2
# mdp/31348/mdp.39015030142080.json.bz2
# mdp/31347/mdp.39015030142072.json.bz2
# mdp/31346/mdp.39015030142064.json.bz2
# mdp/31345/mdp.39015030142056.json.bz2
# ...

# %%
vol = Volume('coo.31924103125021.json.bz2')
vol
# Out:
# <strong><a href='http://hdl.handle.net/2027/coo.31924103125021'>The Indian's friend.</a></strong> by <em>National Indian Association., Women's National Indian Association (U.S.)</em> (1893, 266 pages) - <code>coo.31924103125021</code>

# %%
vol = Volume('coo.31924103125021')
vol
# Out:
# <strong><a href='http://hdl.handle.net/2027/coo.31924103125021'>The Indian's friend.</a></strong> by <em>National Indian Association , Women's National Indian Association (U.S.) </em> (1893, 266 pages) - <code>coo.31924103125021</code>

# %%
rsync -av --no-relative --files-from=pathlist.txt data.analytics.hathitrust.org::features-2020.03/ .
# Out:
#   File "<ipython-input-5-0c36442fbd76>", line 1
#     rsync -av --no-relative --files-from=pathlist.txt data.analytics.hathitrust.org::features-2020.03/ .
#                                        ^
# SyntaxError: invalid syntax
